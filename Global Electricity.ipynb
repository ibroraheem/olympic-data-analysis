# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('global_electricity.csv' )

# %%
df.head()
# Out:
#                 Country        Features  Region   1980   1981   1982   1983  \
# 0               Algeria  net generation  Africa  6.683   7.65  8.824  9.615
# 1                Angola  net generation  Africa  0.905  0.906  0.995  1.028
# 2                 Benin  net generation  Africa  0.005  0.005  0.005  0.005
# 3              Botswana  net generation  Africa  0.443  0.502  0.489  0.434
# 4          Burkina Faso  net generation  Africa  0.098  0.108  0.115  0.117
#
#      1984    1985    1986  ...     2012     2013      2014      2015  \
# 0  10.537  11.569  12.214  ...  53.9845  56.3134  60.39972  64.68244
# 1   1.028   1.028   1.088  ...  6.03408  7.97606   9.21666   9.30914
# 2   0.005   0.005   0.005  ...  0.04612  0.08848   0.22666   0.31056
# 3   0.445   0.456   0.538  ...     0.33  0.86868   2.17628   2.79104
# 4   0.113   0.115   0.122  ...  0.86834  0.98268   1.11808   1.43986
#
#         2016      2017      2018     2019         2020         2021
# ...

# %%
df.isnull().sum()
# Out:
# Country      0
# Features     0
# Region       0
# 1980        28
# 1981        28
# 1982        28
# 1983        28
# 1984        28
# 1985        28
# 1986        28
# 1987        28
# 1988        28
# 1989        28
# 1990        28
# 1991        28
# 1992        28
# 1993        28
# 1994        28
# 1995        28
# 1996        28
# 1997        28
# 1998        28
# 1999        28
# 2000        28
# 2001        28
# 2002        28
# 2003        28
# 2004        28
# 2005        28
# 2006        28
# 2007        28
# 2008        28
# 2009        28
# 2010        28
# 2011        28
# 2012        28
# 2013        28
# 2014        28
# 2015        28
# 2016        28
# 2017        28
# 2018        28
# 2019        28
# 2020        31
# 2021        26
# dtype: int64

# %%
df
# Out:
#                                Country              Features  \
# 0                              Algeria        net generation
# 1                               Angola        net generation
# 2                                Benin        net generation
# 3                             Botswana        net generation
# 4                         Burkina Faso        net generation
# ...                                ...                   ...
# 1605               Trinidad and Tobago  distribution losses
# 1606          Turks and Caicos Islands  distribution losses
# 1607               U.S. Virgin Islands  distribution losses
# 1608                           Uruguay  distribution losses
# 1609                         Venezuela  distribution losses
#
#                        Region     1980     1981     1982     1983     1984  \
# 0                      Africa    6.683     7.65    8.824    9.615   10.537
# 1                      Africa    0.905    0.906    0.995    1.028    1.028
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.info
# Out:
# <bound method DataFrame.info of                                Country              Features  \
# 0                              Algeria        net generation
# 1                               Angola        net generation
# 2                                Benin        net generation
# 3                             Botswana        net generation
# 4                         Burkina Faso        net generation
# ...                                ...                   ...
# 1605               Trinidad and Tobago  distribution losses
# 1606          Turks and Caicos Islands  distribution losses
# 1607               U.S. Virgin Islands  distribution losses
# 1608                           Uruguay  distribution losses
# 1609                         Venezuela  distribution losses
#
#                        Region     1980     1981     1982     1983     1984  \
# 0                      Africa    6.683     7.65    8.824    9.615   10.537
# ...

# %%
df.replace("--", 0, inplace=True)

# %%
df.isnull().sum()
# Out:
# Country      0
# Features     0
# Region       0
# 1980        28
# 1981        28
# 1982        28
# 1983        28
# 1984        28
# 1985        28
# 1986        28
# 1987        28
# 1988        28
# 1989        28
# 1990        28
# 1991        28
# 1992        28
# 1993        28
# 1994        28
# 1995        28
# 1996        28
# 1997        28
# 1998        28
# 1999        28
# 2000        28
# 2001        28
# 2002        28
# 2003        28
# 2004        28
# 2005        28
# 2006        28
# 2007        28
# 2008        28
# 2009        28
# 2010        28
# 2011        28
# 2012        28
# 2013        28
# 2014        28
# 2015        28
# 2016        28
# 2017        28
# 2018        28
# 2019        28
# 2020        31
# 2021        26
# dtype: int64

# %%
df.replace("--", 0, inplace=True)

# %%
df.head()
# Out:
#                 Country        Features  Region   1980   1981   1982   1983  \
# 0               Algeria  net generation  Africa  6.683   7.65  8.824  9.615
# 1                Angola  net generation  Africa  0.905  0.906  0.995  1.028
# 2                 Benin  net generation  Africa  0.005  0.005  0.005  0.005
# 3              Botswana  net generation  Africa  0.443  0.502  0.489  0.434
# 4          Burkina Faso  net generation  Africa  0.098  0.108  0.115  0.117
#
#      1984    1985    1986  ...     2012     2013      2014      2015  \
# 0  10.537  11.569  12.214  ...  53.9845  56.3134  60.39972  64.68244
# 1   1.028   1.028   1.088  ...  6.03408  7.97606   9.21666   9.30914
# 2   0.005   0.005   0.005  ...  0.04612  0.08848   0.22666   0.31056
# 3   0.445   0.456   0.538  ...     0.33  0.86868   2.17628   2.79104
# 4   0.113   0.115   0.122  ...  0.86834  0.98268   1.11808   1.43986
#
#         2016      2017      2018     2019         2020         2021
# ...

# %%
df.isnull().sum()
# Out:
# Country     0
# Features    0
# Region      0
# 1980        0
# 1981        0
# 1982        0
# 1983        0
# 1984        0
# 1985        0
# 1986        0
# 1987        0
# 1988        0
# 1989        0
# 1990        0
# 1991        0
# 1992        0
# 1993        0
# 1994        0
# 1995        0
# 1996        0
# 1997        0
# 1998        0
# 1999        0
# 2000        0
# 2001        0
# 2002        0
# 2003        0
# 2004        0
# 2005        0
# 2006        0
# 2007        0
# 2008        0
# 2009        0
# 2010        0
# 2011        0
# 2012        0
# 2013        0
# 2014        0
# 2015        0
# 2016        0
# 2017        0
# 2018        0
# 2019        0
# 2020        0
# 2021        0
# dtype: int64

# %%
df = df.dropna()

# %%
df.head()
# Out:
#                 Country        Features  Region   1980   1981   1982   1983  \
# 0               Algeria  net generation  Africa  6.683   7.65  8.824  9.615
# 1                Angola  net generation  Africa  0.905  0.906  0.995  1.028
# 2                 Benin  net generation  Africa  0.005  0.005  0.005  0.005
# 3              Botswana  net generation  Africa  0.443  0.502  0.489  0.434
# 4          Burkina Faso  net generation  Africa  0.098  0.108  0.115  0.117
#
#      1984    1985    1986  ...     2012     2013      2014      2015  \
# 0  10.537  11.569  12.214  ...  53.9845  56.3134  60.39972  64.68244
# 1   1.028   1.028   1.088  ...  6.03408  7.97606   9.21666   9.30914
# 2   0.005   0.005   0.005  ...  0.04612  0.08848   0.22666   0.31056
# 3   0.445   0.456   0.538  ...     0.33  0.86868   2.17628   2.79104
# 4   0.113   0.115   0.122  ...  0.86834  0.98268   1.11808   1.43986
#
#         2016      2017      2018     2019         2020         2021
# ...

# %%
year_columns = [str(year) for year in range(1980, 2022)]
df[year_columns] = df[year_columns].apply(pd.to_numeric, errors='coerce')

# %%
year_columns = [str(year) for year in range(1980, 2022)]
df[year_columns] = df[year_columns].apply(pd.to_numeric, errors='coerce')

# %%
remaining_unknowns = (df[year_columns] == '--').sum().sum()

# %%
remaining_unknowns
# Out:
# 0

# %%
total_stats = df[year_columns].sum()

# %%
total_stats = df[year_columns].sum()
plt.figure(figsize=(12, 6))
total_stats.plot(kind='line')
plt.title('Total Electricity Statistics from 1980 to 2021')
plt.xlabel('Year')
plt.ylabel('Total Electricity Statistics')
plt.grid(True)
plt.show()

# %%
top_countries_1980 = df[['Country', '1980']].sort_values(by='1980', ascending=False).head(23)
plt.figure(figsize=(12, 6))
sns.barplot(data=top_countries_1980, x='1980', y='Country')
plt.title('Top 10 Countries by Electricity Statistics in 1980')
plt.xlabel('Electricity Statistics in 1980 (MW)')
plt.ylabel('Country')
plt.grid(True)
plt.show()

# %%
top_countries_2020 = df[['Country', '2020']].sort_values(by='2020', ascending=False).head(23)
plt.figure(figsize=(12, 6))
sns.barplot(data=top_countries_2020, x='2020', y='Country')
plt.title('Top 10 Countries by Electricity Statistics in 2020')
plt.xlabel('Electricity Statistics in 2020 (MW)')
plt.ylabel('Country')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(20, 20))
corr = df[year_columns].corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap of Electricity Statistics Over the Years')
plt.show()

# %%
plt.figure(figsize=(14, 8))
region_stats_1980 = df.groupby('Region')['1980'].sum().sort_values(ascending=False)
sns.barplot(x=region_stats_1980.values, y=region_stats_1980.index)
plt.title('Electricity Statistics by Region in 1980')
plt.xlabel('Electricity Statistics')
plt.ylabel('Region')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(14, 8))
region_stats_2020 = df.groupby('Region')['2020'].sum().sort_values(ascending=False)
sns.barplot(x=region_stats_2020.values, y=region_stats_2020.index)
plt.title('Electricity Statistics by Region in 2020')
plt.xlabel('Electricity Statistics')
plt.ylabel('Region')
plt.grid(True)
plt.show()

# %%
f, axes = plt.subplots(2,2, figsize = (10,10))
sns.set_style('darkgrid')
fig1 = sns.barplot(x=region_stats_2020.values, y=region_stats_2020.index, ax= axes[0,1])
plt.title('Electricity Statistics by Region in 2020')
plt.xlabel('Power (MW)')
plt.ylabel('Region')
plt.grid(True)
fig2 = sns.barplot(x=region_stats_1980.values, y=region_stats_1980.index, ax = axes[0,0])
plt.title('Electricity Statistics by Region in 1980')
plt.xlabel('Power (MW)')
plt.ylabel('Region')
plt.grid(True) 
fig3 = sns.barplot(data=top_countries_1980, x='1980', y='Country', ax = axes[1,0])
plt.title('Top 10 Countries by Electricity Statistics in 1980')
plt.xlabel('Power (MW)')
plt.ylabel('Country')
plt.grid(True)
fig4 = sns.barplot(data=top_countries_2020, x='2020', y='Country', ax = axes[1,1])
plt.title('Top 10 Countries by Electricity Statistics in 2020')
plt.xlabel('Power (MW)')
plt.ylabel('Country')
plt.grid(True)
plt.show()
